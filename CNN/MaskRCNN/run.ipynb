# %%
# !python train.py --use-cuda --dataset=voc --data-dir=D:/MachineLearning/Datasets/VOC2012 --iters=100 --epochs=10
# Out:
# cuda: True
# available GPU(s): 1
# 0: {'name': 'NVIDIA GeForce RTX 4050 Laptop GPU', 'capability': [8, 9], 'total_momory': 6.0, 'sm_count': 20}
#
# Device: cuda
# Namespace(use_cuda=True, dataset='voc', data_dir='D:/MachineLearning/Datasets/VOC2012', ckpt_path='./maskrcnn_voc.pth', results='.\\maskrcnn_results.pth', seed=3, lr_steps=[6, 7], lr=0.00125, momentum=0.9, weight_decay=0.0001, epochs=10, iters=100, print_freq=100, warmup_iters=1463)
#
# Loaded checkpoint: already trained 0 epochs; to 10 epochs
#
# Epoch: 1
# Hyperparameter lr_epoch: 0.00125, factor: 1.00000
# 0	 0.687	0.113	3.559	0.103	2.045
# Time per iter: 190.3, Total: 142.3, Model: 85.9, Backward: 15.7
# iter: 115.3, total: 74.5, model: 73.3
# loading annotations into memory...
# Done (t=0.05s)
# creating index...
# index created!
# accumulate: 0.0s
# Training: 19.0 s, Evaluation: 11.6 s
# {'bbox AP': 0.0, 'mask AP': 0.0}
#
# Epoch: 2
# Hyperparameter lr_epoch: 0.00125, factor: 1.00000
# ...
